# %%
import yfinance as yf
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque

# 1. Download historical stock data and feature engineering
symbol = "AAPL"
start_date = "2020-01-01"
end_date = "2025-02-14"

data = yf.download(symbol, start=start_date, end=end_date)

data['SMA_5'] = data['Close'].rolling(window=5).mean()
data['SMA_20'] = data['Close'].rolling(window=20).mean()
data['Returns'] = data['Close'].pct_change()

data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)

# 2. Define safe float function (to fix future warnings)
def safe_float(val):
    return float(val.iloc[0]) if isinstance(val, pd.Series) else float(val)

# 3. Define trading environment with balance tracking
class TradingEnvironment:
    def __init__(self, data, initial_balance=10000):
        self.data = data.reset_index(drop=True)
        self.index = 0
        self.done = False
        self.initial_balance = initial_balance
        self.balance = initial_balance
        self.position = 0  # number of shares held
        self.last_price = safe_float(self.data.loc[self.index, 'Close'])

    def reset(self):
        self.index = 0
        self.done = False
        self.balance = self.initial_balance
        self.position = 0
        self.last_price = safe_float(self.data.loc[self.index, 'Close'])
        return self._get_state()

    def step(self, action):
        # Actions: 0 = HOLD, 1 = BUY, 2 = SELL
        self.index += 1
        if self.index >= len(self.data) - 1:
            self.done = True

        price = safe_float(self.data.loc[self.index, 'Close'])
        reward = 0

        if action == 1:  # BUY
            if self.balance >= price:
                self.position += 1
                self.balance -= price
        elif action == 2:  # SELL
            if self.position > 0:
                self.position -= 1
                self.balance += price

        # Reward is unrealized profit on held shares
        reward = (price - self.last_price) * self.position
        self.last_price = price

        next_state = self._get_state()
        return next_state, reward, self.done, {}

    def _get_state(self):
        idx = self.index
        return np.array([
            safe_float(self.data.loc[idx, 'Close']),
            safe_float(self.data.loc[idx, 'SMA_5']),
            safe_float(self.data.loc[idx, 'SMA_20']),
            safe_float(self.data.loc[idx, 'Returns'])
        ])

# 4. Define DQN neural network
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# 5. Define DQN agent
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95  # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = DQN(state_size, action_size)
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if random.random() < self.epsilon:
            return random.choice([0,1,2])  # HOLD, BUY, SELL
        state = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            q_values = self.model(state)
        return torch.argmax(q_values).item()

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)

        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)
                target += self.gamma * torch.max(self.model(next_state_tensor)).item()

            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            target_tensor = self.model(state_tensor).clone().detach()
            target_tensor[0][action] = target

            self.optimizer.zero_grad()
            output = self.model(state_tensor)
            loss = self.criterion(output, target_tensor)
            loss.backward()
            self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# 6. Training loop
env = TradingEnvironment(data)
agent = DQNAgent(state_size=4, action_size=3)
batch_size = 32
episodes = 500
total_rewards = []

for episode in range(episodes):
    state = env.reset()
    done = False
    total_reward = 0

    while not done:
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

    agent.replay(batch_size)
    total_rewards.append(total_reward)
    print(f"Episode {episode+1}/{episodes}, Total Reward: {total_reward:.2f}")

print("Training Complete!")

# 7. Testing phase - evaluation
agent.epsilon = agent.epsilon_min  # turn off exploration for testing
test_env = TradingEnvironment(data)
state = test_env.reset()
done = False

while not done:
    action = agent.act(state)
    next_state, reward, done, _ = test_env.step(action)
    state = next_state if next_state is not None else state

final_balance = test_env.balance + test_env.position * safe_float(data.loc[test_env.index, 'Close'])
profit = final_balance - test_env.initial_balance
print(f"Final Balance after testing: ${final_balance:.2f}")
print(f"Total Profit: ${profit:.2f}")
# Out:
# /tmp/ipython-input-30-3051135037.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# Episode 1/500, Total Reward: 4137.93
# Episode 2/500, Total Reward: 3521.20
# Episode 3/500, Total Reward: 787.63
# Episode 4/500, Total Reward: 3936.66
# Episode 5/500, Total Reward: 1077.54
# Episode 6/500, Total Reward: 4014.79
# Episode 7/500, Total Reward: 1192.12
# Episode 8/500, Total Reward: 1641.85
# Episode 9/500, Total Reward: 507.37
# Episode 10/500, Total Reward: 8424.83
# Episode 11/500, Total Reward: 482.04
# Episode 12/500, Total Reward: 2536.26
# Episode 13/500, Total Reward: 434.77
# Episode 14/500, Total Reward: 1659.23
# Episode 15/500, Total Reward: 495.00
# Episode 16/500, Total Reward: 872.17
# Episode 17/500, Total Reward: 2576.28
# Episode 18/500, Total Reward: 7865.08
# Episode 19/500, Total Reward: 8135.48
# Episode 20/500, Total Reward: 7317.47
# Episode 21/500, Total Reward: 8457.16
# Episode 22/500, Total Reward: 7560.93
# Episode 23/500, Total Reward: 10198.87
# Episode 24/500, Total Reward: 8954.17
# Episode 25/500, Total Reward: 552.01
# Episode 26/500, Total Reward: 641.58
# Episode 27/500, Total Reward: 134.03
# Episode 28/500, Total Reward: 5475.93
# Episode 29/500, Total Reward: 8333.35
# Episode 30/500, Total Reward: 9422.54
# Episode 31/500, Total Reward: 639.28
# Episode 32/500, Total Reward: 165.46
# Episode 33/500, Total Reward: 9488.51
# Episode 34/500, Total Reward: 581.07
# Episode 35/500, Total Reward: 1981.85
# Episode 36/500, Total Reward: 2137.32
# Episode 37/500, Total Reward: 1792.97
# Episode 38/500, Total Reward: 295.07
# Episode 39/500, Total Reward: 246.72
# Episode 40/500, Total Reward: 192.02
# Episode 41/500, Total Reward: 1956.23
# Episode 42/500, Total Reward: 3253.39
# Episode 43/500, Total Reward: 11799.56
# Episode 44/500, Total Reward: 8749.91
# Episode 45/500, Total Reward: 9830.37
# Episode 46/500, Total Reward: 359.73
# Episode 47/500, Total Reward: 1438.96
# Episode 48/500, Total Reward: 846.02
# Episode 49/500, Total Reward: 10428.01
# Episode 50/500, Total Reward: 11593.15
# Episode 51/500, Total Reward: 241.20
# Episode 52/500, Total Reward: 10826.18
# Episode 53/500, Total Reward: 10639.19
# Episode 54/500, Total Reward: 13211.21
# Episode 55/500, Total Reward: 12153.80
# Episode 56/500, Total Reward: 421.83
# Episode 57/500, Total Reward: 201.37
# Episode 58/500, Total Reward: 3562.04
# Episode 59/500, Total Reward: 235.33
# Episode 60/500, Total Reward: 13506.65
# Episode 61/500, Total Reward: 13011.42
# Episode 62/500, Total Reward: 252.83
# Episode 63/500, Total Reward: 13841.37
# Episode 64/500, Total Reward: 13182.23
# Episode 65/500, Total Reward: 13170.19
# Episode 66/500, Total Reward: 12703.59
# Episode 67/500, Total Reward: 11292.98
# Episode 68/500, Total Reward: 13552.29
# Episode 69/500, Total Reward: 970.56
# Episode 70/500, Total Reward: 13550.13
# Episode 71/500, Total Reward: 1224.71
# Episode 72/500, Total Reward: 987.55
# Episode 73/500, Total Reward: 2067.58
# Episode 74/500, Total Reward: 180.85
# Episode 75/500, Total Reward: 11.47
# Episode 76/500, Total Reward: 61.53
# Episode 77/500, Total Reward: 2359.64
# Episode 78/500, Total Reward: 2665.10
# Episode 79/500, Total Reward: 14474.08
# Episode 80/500, Total Reward: 2382.55
# Episode 81/500, Total Reward: 14245.61
# Episode 82/500, Total Reward: -7.42
# Episode 83/500, Total Reward: 39.66
# Episode 84/500, Total Reward: 213.36
# Episode 85/500, Total Reward: 160.11
# Episode 86/500, Total Reward: 12810.93
# Episode 87/500, Total Reward: 14353.11
# Episode 88/500, Total Reward: 1061.82
# Episode 89/500, Total Reward: 13422.90
# Episode 90/500, Total Reward: 15108.08
# Episode 91/500, Total Reward: 14086.87
# Episode 92/500, Total Reward: 14529.29
# Episode 93/500, Total Reward: 1535.27
# Episode 94/500, Total Reward: 1439.14
# Episode 95/500, Total Reward: 14296.57
# Episode 96/500, Total Reward: 2612.17
# Episode 97/500, Total Reward: 13831.23
# Episode 98/500, Total Reward: 14745.47
# Episode 99/500, Total Reward: 14146.83
# Episode 100/500, Total Reward: 14738.99
# Episode 101/500, Total Reward: 13778.40
# Episode 102/500, Total Reward: 15861.06
# Episode 103/500, Total Reward: 13911.22
# Episode 104/500, Total Reward: 14242.37
# Episode 105/500, Total Reward: 16447.82
# Episode 106/500, Total Reward: 2337.80
# Episode 107/500, Total Reward: 114.06
# Episode 108/500, Total Reward: 132.54
# Episode 109/500, Total Reward: 6.97
# Episode 110/500, Total Reward: 882.08
# Episode 111/500, Total Reward: 38.81
# Episode 112/500, Total Reward: 109.84
# Episode 113/500, Total Reward: 1566.77
# Episode 114/500, Total Reward: 1289.58
# Episode 115/500, Total Reward: 13996.23
# Episode 116/500, Total Reward: 16141.93
# Episode 117/500, Total Reward: 1439.87
# Episode 118/500, Total Reward: 15701.97
# Episode 119/500, Total Reward: 16734.15
# Episode 120/500, Total Reward: 15929.83
# Episode 121/500, Total Reward: 1242.78
# Episode 122/500, Total Reward: 15856.68
# Episode 123/500, Total Reward: 13.38
# Episode 124/500, Total Reward: 103.66
# Episode 125/500, Total Reward: 2189.74
# Episode 126/500, Total Reward: 902.07
# Episode 127/500, Total Reward: 4792.55
# Episode 128/500, Total Reward: 1308.92
# Episode 129/500, Total Reward: 15.78
# Episode 130/500, Total Reward: 93.11
# Episode 131/500, Total Reward: -38.32
# Episode 132/500, Total Reward: 130.28
# Episode 133/500, Total Reward: 5417.10
# Episode 134/500, Total Reward: 137.36
# Episode 135/500, Total Reward: 5308.96
# Episode 136/500, Total Reward: 4587.05
# Episode 137/500, Total Reward: 138.67
# Episode 138/500, Total Reward: 68.22
# Episode 139/500, Total Reward: 68.64
# Episode 140/500, Total Reward: 10799.60
# Episode 141/500, Total Reward: 15414.88
# Episode 142/500, Total Reward: 16653.27
# Episode 143/500, Total Reward: 36.81
# Episode 144/500, Total Reward: 66.49
# Episode 145/500, Total Reward: 15377.60
# Episode 146/500, Total Reward: 16139.28
# Episode 147/500, Total Reward: 15612.58
# Episode 148/500, Total Reward: 16554.78
# Episode 149/500, Total Reward: 852.71
# Episode 150/500, Total Reward: 1428.56
# Episode 151/500, Total Reward: 989.36
# Episode 152/500, Total Reward: 3251.61
# Episode 153/500, Total Reward: 648.85
# Episode 154/500, Total Reward: 1971.08
# Episode 155/500, Total Reward: 49.49
# Episode 156/500, Total Reward: -19.82
# Episode 157/500, Total Reward: 138.80
# Episode 158/500, Total Reward: 71.37
# Episode 159/500, Total Reward: 2678.26
# Episode 160/500, Total Reward: 16208.35
# Episode 161/500, Total Reward: 89.55
# Episode 162/500, Total Reward: 47.29
# Episode 163/500, Total Reward: 25.95
# Episode 164/500, Total Reward: 87.67
# Episode 165/500, Total Reward: 21.29
# Episode 166/500, Total Reward: 5.72
# Episode 167/500, Total Reward: -80.48
# Episode 168/500, Total Reward: -15.49
# Episode 169/500, Total Reward: 93.08
# Episode 170/500, Total Reward: 1.75
# Episode 171/500, Total Reward: 33.50
# Episode 172/500, Total Reward: 1743.82
# Episode 173/500, Total Reward: 51.83
# Episode 174/500, Total Reward: 2206.48
# Episode 175/500, Total Reward: 1672.77
# Episode 176/500, Total Reward: 2113.21
# Episode 177/500, Total Reward: -77.54
# Episode 178/500, Total Reward: 46.92
# Episode 179/500, Total Reward: 74.17
# Episode 180/500, Total Reward: 85.73
# Episode 181/500, Total Reward: 2608.95
# Episode 182/500, Total Reward: 2130.78
# Episode 183/500, Total Reward: 2179.35
# Episode 184/500, Total Reward: 44.66
# Episode 185/500, Total Reward: 666.41
# Episode 186/500, Total Reward: 32.58
# Episode 187/500, Total Reward: -42.08
# Episode 188/500, Total Reward: -18.25
# Episode 189/500, Total Reward: 1005.91
# Episode 190/500, Total Reward: 692.59
# Episode 191/500, Total Reward: 1384.49
# Episode 192/500, Total Reward: 15811.19
# Episode 193/500, Total Reward: 17599.01
# Episode 194/500, Total Reward: 17567.63
# Episode 195/500, Total Reward: 17432.52
# Episode 196/500, Total Reward: 17803.13
# Episode 197/500, Total Reward: 16375.18
# Episode 198/500, Total Reward: 18030.27
# Episode 199/500, Total Reward: 18156.86
# Episode 200/500, Total Reward: 17634.16
# Episode 201/500, Total Reward: 18364.66
# Episode 202/500, Total Reward: 17568.12
# Episode 203/500, Total Reward: 17473.36
# Episode 204/500, Total Reward: 17279.50
# Episode 205/500, Total Reward: 18197.44
# Episode 206/500, Total Reward: 17939.33
# Episode 207/500, Total Reward: 17854.73
# Episode 208/500, Total Reward: 18246.08
# Episode 209/500, Total Reward: 126.71
# Episode 210/500, Total Reward: -25.17
# Episode 211/500, Total Reward: -35.44
# Episode 212/500, Total Reward: 48.16
# Episode 213/500, Total Reward: 14189.85
# Episode 214/500, Total Reward: 409.79
# Episode 215/500, Total Reward: 739.50
# Episode 216/500, Total Reward: 3351.94
# Episode 217/500, Total Reward: 9365.27
# Episode 218/500, Total Reward: 2010.29
# Episode 219/500, Total Reward: 663.53
# Episode 220/500, Total Reward: 1008.94
# Episode 221/500, Total Reward: 615.41
# Episode 222/500, Total Reward: 2690.91
# Episode 223/500, Total Reward: 1731.61
# Episode 224/500, Total Reward: 2152.69
# Episode 225/500, Total Reward: 2451.20
# Episode 226/500, Total Reward: 926.74
# Episode 227/500, Total Reward: 1887.73
# Episode 228/500, Total Reward: 918.42
# Episode 229/500, Total Reward: 1329.92
# Episode 230/500, Total Reward: 23.84
# Episode 231/500, Total Reward: 32.39
# Episode 232/500, Total Reward: 19049.62
# Episode 233/500, Total Reward: 16857.52
# Episode 234/500, Total Reward: 18814.72
# Episode 235/500, Total Reward: 17510.92
# Episode 236/500, Total Reward: 18277.91
# Episode 237/500, Total Reward: 664.44
# Episode 238/500, Total Reward: 749.73
# Episode 239/500, Total Reward: 18077.84
# Episode 240/500, Total Reward: 60.57
# Episode 241/500, Total Reward: 17136.62
# Episode 242/500, Total Reward: 17181.54
# Episode 243/500, Total Reward: 18623.47
# Episode 244/500, Total Reward: 18121.64
# Episode 245/500, Total Reward: 19245.61
# Episode 246/500, Total Reward: 19186.54
# Episode 247/500, Total Reward: 17912.54
# Episode 248/500, Total Reward: 11.84
# Episode 249/500, Total Reward: 18027.00
# Episode 250/500, Total Reward: 17753.39
# Episode 251/500, Total Reward: 18792.32
# Episode 252/500, Total Reward: 18975.35
# Episode 253/500, Total Reward: 18199.11
# Episode 254/500, Total Reward: 18855.43
# Episode 255/500, Total Reward: 18789.43
# Episode 256/500, Total Reward: 19352.09
# Episode 257/500, Total Reward: 18693.75
# Episode 258/500, Total Reward: 17618.97
# Episode 259/500, Total Reward: 547.16
# Episode 260/500, Total Reward: 1806.93
# Episode 261/500, Total Reward: 18487.95
# Episode 262/500, Total Reward: 18584.70
# Episode 263/500, Total Reward: 1291.36
# Episode 264/500, Total Reward: 19082.64
# Episode 265/500, Total Reward: 18123.30
# Episode 266/500, Total Reward: 19003.07
# Episode 267/500, Total Reward: 19017.11
# Episode 268/500, Total Reward: 15182.70
# Episode 269/500, Total Reward: 18787.47
# Episode 270/500, Total Reward: -6.08
# Episode 271/500, Total Reward: 10.90
# Episode 272/500, Total Reward: -20.65
# Episode 273/500, Total Reward: 10.79
# Episode 274/500, Total Reward: 19232.76
# Episode 275/500, Total Reward: 2395.40
# Episode 276/500, Total Reward: 19434.44
# Episode 277/500, Total Reward: 18799.51
# Episode 278/500, Total Reward: 18247.80
# Episode 279/500, Total Reward: 19709.34
# Episode 280/500, Total Reward: 1575.10
# Episode 281/500, Total Reward: 2229.21
# Episode 282/500, Total Reward: 1863.06
# Episode 283/500, Total Reward: 514.76
# Episode 284/500, Total Reward: 18079.81
# Episode 285/500, Total Reward: 18964.45
# Episode 286/500, Total Reward: 18374.59
# Episode 287/500, Total Reward: 19242.24
# Episode 288/500, Total Reward: 18842.23
# Episode 289/500, Total Reward: 19763.51
# Episode 290/500, Total Reward: 18543.36
# Episode 291/500, Total Reward: 19224.02
# Episode 292/500, Total Reward: 19025.85
# Episode 293/500, Total Reward: 18736.89
# Episode 294/500, Total Reward: 18447.55
# Episode 295/500, Total Reward: 19372.41
# Episode 296/500, Total Reward: -2.74
# Episode 297/500, Total Reward: 15.00
# Episode 298/500, Total Reward: -17.93
# Episode 299/500, Total Reward: -52.84
# Episode 300/500, Total Reward: 572.47
# Episode 301/500, Total Reward: 761.06
# Episode 302/500, Total Reward: 304.69
# Episode 303/500, Total Reward: -46.54
# Episode 304/500, Total Reward: 313.71
# Episode 305/500, Total Reward: 19752.79
# Episode 306/500, Total Reward: 20004.31
# Episode 307/500, Total Reward: 19394.79
# Episode 308/500, Total Reward: 19302.18
# Episode 309/500, Total Reward: 42.28
# Episode 310/500, Total Reward: -11.51
# Episode 311/500, Total Reward: -1.58
# Episode 312/500, Total Reward: 20.97
# Episode 313/500, Total Reward: 1798.14
# Episode 314/500, Total Reward: 956.96
# Episode 315/500, Total Reward: 2115.91
# Episode 316/500, Total Reward: 344.80
# Episode 317/500, Total Reward: 16.85
# Episode 318/500, Total Reward: 0.64
# Episode 319/500, Total Reward: -1.98
# Episode 320/500, Total Reward: 304.73
# Episode 321/500, Total Reward: 821.35
# Episode 322/500, Total Reward: 18651.12
# Episode 323/500, Total Reward: 19657.98
# Episode 324/500, Total Reward: 19925.87
# Episode 325/500, Total Reward: 18777.17
# Episode 326/500, Total Reward: 18528.72
# Episode 327/500, Total Reward: 19280.61
# Episode 328/500, Total Reward: 18770.33
# Episode 329/500, Total Reward: 18977.14
# Episode 330/500, Total Reward: 19770.49
# Episode 331/500, Total Reward: 19024.18
# Episode 332/500, Total Reward: 19506.91
# Episode 333/500, Total Reward: 19777.35
# Episode 334/500, Total Reward: 19512.16
# Episode 335/500, Total Reward: 1735.21
# Episode 336/500, Total Reward: 2358.72
# Episode 337/500, Total Reward: 279.77
# Episode 338/500, Total Reward: 25.79
# Episode 339/500, Total Reward: 75.98
# Episode 340/500, Total Reward: 19006.36
# Episode 341/500, Total Reward: 18821.04
# Episode 342/500, Total Reward: 20181.28
# Episode 343/500, Total Reward: 19812.00
# Episode 344/500, Total Reward: 20203.53
# Episode 345/500, Total Reward: 19423.35
# Episode 346/500, Total Reward: 19097.94
# Episode 347/500, Total Reward: 18574.58
# Episode 348/500, Total Reward: 20218.21
# Episode 349/500, Total Reward: 19760.24
# Episode 350/500, Total Reward: 19771.28
# Episode 351/500, Total Reward: 20232.00
# Episode 352/500, Total Reward: 120.91
# Episode 353/500, Total Reward: 20324.93
# Episode 354/500, Total Reward: 18767.66
# Episode 355/500, Total Reward: 18634.86
# Episode 356/500, Total Reward: 18676.41
# Episode 357/500, Total Reward: 18328.69
# Episode 358/500, Total Reward: 1303.56
# Episode 359/500, Total Reward: 1334.80
# Episode 360/500, Total Reward: 18699.62
# Episode 361/500, Total Reward: 19975.02
# Episode 362/500, Total Reward: 19328.36
# Episode 363/500, Total Reward: 19.31
# Episode 364/500, Total Reward: 19989.62
# Episode 365/500, Total Reward: 19986.66
# Episode 366/500, Total Reward: 18032.10
# Episode 367/500, Total Reward: 20474.56
# Episode 368/500, Total Reward: 18822.39
# Episode 369/500, Total Reward: 19200.29
# Episode 370/500, Total Reward: 19245.85
# Episode 371/500, Total Reward: -10.47
# Episode 372/500, Total Reward: 20452.76
# Episode 373/500, Total Reward: 20237.14
# Episode 374/500, Total Reward: 19323.93
# Episode 375/500, Total Reward: 20241.62
# Episode 376/500, Total Reward: 19724.16
# Episode 377/500, Total Reward: 19770.16
# Episode 378/500, Total Reward: 19922.31
# Episode 379/500, Total Reward: 19932.14
# Episode 380/500, Total Reward: 19468.81
# Episode 381/500, Total Reward: 20252.47
# Episode 382/500, Total Reward: 20739.64
# Episode 383/500, Total Reward: 19934.57
# Episode 384/500, Total Reward: 20005.67
# Episode 385/500, Total Reward: 20300.89
# Episode 386/500, Total Reward: 19046.67
# Episode 387/500, Total Reward: 19536.59
# Episode 388/500, Total Reward: 19688.79
# Episode 389/500, Total Reward: 19736.94
# Episode 390/500, Total Reward: 20435.16
# Episode 391/500, Total Reward: 19578.43
# Episode 392/500, Total Reward: 19789.48
# Episode 393/500, Total Reward: 19554.55
# Episode 394/500, Total Reward: 19693.87
# Episode 395/500, Total Reward: 19966.47
# Episode 396/500, Total Reward: 20214.38
# Episode 397/500, Total Reward: 20220.48
# Episode 398/500, Total Reward: 19946.63
# Episode 399/500, Total Reward: 19233.37
# Episode 400/500, Total Reward: 20133.07
# Episode 401/500, Total Reward: 23.35
# Episode 402/500, Total Reward: 7.07
# Episode 403/500, Total Reward: -31.97
# Episode 404/500, Total Reward: 19587.09
# Episode 405/500, Total Reward: 820.90
# Episode 406/500, Total Reward: 427.20
# Episode 407/500, Total Reward: 19972.94
# Episode 408/500, Total Reward: 18620.21
# Episode 409/500, Total Reward: 20158.43
# Episode 410/500, Total Reward: 258.25
# Episode 411/500, Total Reward: 509.84
# Episode 412/500, Total Reward: 19544.15
# Episode 413/500, Total Reward: 19790.25
# Episode 414/500, Total Reward: 19958.34
# Episode 415/500, Total Reward: 19897.82
# Episode 416/500, Total Reward: 1986.46
# Episode 417/500, Total Reward: 196.00
# Episode 418/500, Total Reward: 1040.08
# Episode 419/500, Total Reward: 632.00
# Episode 420/500, Total Reward: 1964.21
# Episode 421/500, Total Reward: 814.09
# Episode 422/500, Total Reward: 20110.29
# Episode 423/500, Total Reward: 20419.60
# Episode 424/500, Total Reward: 19964.29
# Episode 425/500, Total Reward: 20383.85
# Episode 426/500, Total Reward: 20226.71
# Episode 427/500, Total Reward: 20266.50
# Episode 428/500, Total Reward: 20367.36
# Episode 429/500, Total Reward: 20707.14
# Episode 430/500, Total Reward: 19414.95
# Episode 431/500, Total Reward: 20051.61
# Episode 432/500, Total Reward: 19954.41
# Episode 433/500, Total Reward: 20670.91
# Episode 434/500, Total Reward: 20465.58
# Episode 435/500, Total Reward: 19561.79
# Episode 436/500, Total Reward: 20504.17
# Episode 437/500, Total Reward: 19261.00
# Episode 438/500, Total Reward: 20014.46
# Episode 439/500, Total Reward: 19773.25
# Episode 440/500, Total Reward: 16.67
# Episode 441/500, Total Reward: 20922.72
# Episode 442/500, Total Reward: 20367.71
# Episode 443/500, Total Reward: 20493.37
# Episode 444/500, Total Reward: 20642.65
# Episode 445/500, Total Reward: 20232.85
# Episode 446/500, Total Reward: 19990.36
# Episode 447/500, Total Reward: 20704.76
# Episode 448/500, Total Reward: 19965.51
# Episode 449/500, Total Reward: 20038.89
# Episode 450/500, Total Reward: 20894.58
# Episode 451/500, Total Reward: 20097.42
# Episode 452/500, Total Reward: 20670.00
# Episode 453/500, Total Reward: 20729.21
# Episode 454/500, Total Reward: 20146.41
# Episode 455/500, Total Reward: 19755.97
# Episode 456/500, Total Reward: 20781.54
# Episode 457/500, Total Reward: 20452.31
# Episode 458/500, Total Reward: 20911.39
# Episode 459/500, Total Reward: 19727.62
# Episode 460/500, Total Reward: 19707.63
# Episode 461/500, Total Reward: 20144.03
# Episode 462/500, Total Reward: 19569.70
# Episode 463/500, Total Reward: 20424.73
# Episode 464/500, Total Reward: 20632.99
# Episode 465/500, Total Reward: 19512.04
# Episode 466/500, Total Reward: 20973.66
# Episode 467/500, Total Reward: 20221.56
# Episode 468/500, Total Reward: 20654.47
# Episode 469/500, Total Reward: 20411.33
# Episode 470/500, Total Reward: 20258.65
# Episode 471/500, Total Reward: 19745.48
# Episode 472/500, Total Reward: 20454.43
# Episode 473/500, Total Reward: 20267.59
# Episode 474/500, Total Reward: -3.52
# Episode 475/500, Total Reward: 0.93
# Episode 476/500, Total Reward: 20238.26
# Episode 477/500, Total Reward: 1010.46
# Episode 478/500, Total Reward: 279.95
# Episode 479/500, Total Reward: 19979.92
# Episode 480/500, Total Reward: 20975.80
# Episode 481/500, Total Reward: 994.44
# Episode 482/500, Total Reward: 1225.25
# Episode 483/500, Total Reward: 354.55
# Episode 484/500, Total Reward: 4.48
# Episode 485/500, Total Reward: 19.63
# Episode 486/500, Total Reward: 20084.24
# Episode 487/500, Total Reward: 0.11
# Episode 488/500, Total Reward: 20230.74
# Episode 489/500, Total Reward: 20655.62
# Episode 490/500, Total Reward: 20733.85
# Episode 491/500, Total Reward: 9.37
# Episode 492/500, Total Reward: 11.47
# Episode 493/500, Total Reward: 21131.58
# Episode 494/500, Total Reward: 20690.08
# Episode 495/500, Total Reward: 37.67
# Episode 496/500, Total Reward: 20209.22
# Episode 497/500, Total Reward: 20548.86
# Episode 498/500, Total Reward: 19975.86
# Episode 499/500, Total Reward: 599.19
# Episode 500/500, Total Reward: 20295.03
# Training Complete!
# Final Balance after testing: $30919.69
# Total Profit: $20919.69
